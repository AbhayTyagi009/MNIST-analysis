# %% [markdown]
# #MNIST Dataset

# %% [markdown]
# The MNIST database (Modified National Institute of Standards and Technology database) is a large database of handwritten digits that is commonly used for training various image processing systems.

# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Let us load the data first into four variables.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [markdown]
# The MNIST dataset is a set of handwritten data. Each picture is greyscale and has a dimension of 28X28. Thus, we get a total of 784 pixels.

# %%
image_index = 0
print(y_train[image_index])
plt.imshow(x_train[image_index], cmap='Greys')
# Out:
# 5

# %% [markdown]
# Now, to see the shape of the dataset.

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_test.shape
# Out:
# (10000,)
